# %% [markdown]
# <img src = "https://escp.eu/sites/default/files/logo/ESCP-logo-white-misalign.svg" width = 400 style="background-color: #240085;">
# <h1 align=center><font size = 6>ESCP Business School</font></h1>
# <h3 align=center><font size = 5>SCOR Datathon</font><br/>
# <font size = 3>The Data Science Challenge Bridging Indian Agricultureal Protection Gap</font></h3>
# <h6 align=center>Chapter 3B - Analysis to Clustering Methods (Kharif - State Level)</h6>

# %% [markdown]
# Last Updated: December 09, 2021\
# Author: Group 21 - Anniek Brink, Jeanne Dubois, and Resha Dirga

# %% [markdown]
# <h3>Chapter Objectives</h3>
#
# <p>This chapter aims to define the best clustering methods to use for the datasets. There are <b><u>four</u></b> methods that we are going to test on this chapter:</p>
#
# <ul>
#     <li>KMeans Clustering</li>
#     <li>Agglomerative Hierarchical Clustering</li>
#     <li>Density-Based Spatial Clustering of Applications with Noise (DBSCAN)</li>
#     <li>Mean-Shift Clustering</li>
# </ul>
#
# <b><i>Source:</i></b> <a href="https://towardsdatascience.com/the-5-clustering-algorithms-data-scientists-need-to-know-a36d136ef68">https://towardsdatascience.com/the-5-clustering-algorithms-data-scientists-need-to-know-a36d136ef68</a>

# %% [markdown]
# <h3>Chapter 1: Import modules</h3>
# <p>This chapter lists all modules that being used on this document. The module import process will be performed on this chapter</p>

# %%
import numpy as np
import pandas as pd

from sklearn import metrics

import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
import pickle

# %% [markdown]
# <h3>Chapter 2: Data Loading and Initial Plotting</h3>
# <p>This chapter reads the data and provides a scatter plot as an initial overview. The chapter also gives an overview of value distribution using a histogram</p>

# %%
filename = "datasets_preprocessed/states_kharif_preprocessed_to_cluster.csv"

# %%
df = pd.read_csv(filename, delimiter=";", index_col = 0)

# %%
df = df.dropna(axis=1, how='all')
df = df.dropna()
data_to_clusters = df.drop(columns=['ID'])

# %%
# View datapoints on plot charts

plt.scatter(df['threshold_yield'], df['loss_calculation'])
plt.title("Loss Calculation Values")
plt.xlabel("Threshold Yield")
plt.ylabel("Loss Calculation")
plt.show()

# %%
plt.hist(df['loss_calculation'], density=False, bins=1000)  # density=False would make counts
plt.ylabel('Frequency')
plt.xlabel('Loss Calculation');

# %% [markdown]
# <h3>Chapter 3: Modelling</h3>
# <p>This chapter define and compile the model, incuding choosing the best hyperparameters for the model. This chapter will test several model and determine the best models based on analysis.
# </p>

# %% [markdown]
# <h5>Method 1 - KMeans Clustering</h5>

# %%
# Import necessary modules
import faiss

# %%
data_to_clusters = data_to_clusters.to_numpy().astype(np.float32)

# %%
# Determine best k for clustering (check range from 1 to 10)

# Compile inertia values
Sum_of_squared_distances = []
k_test = range(2,13)

x = data_to_clusters.copy(order='C') # define datasets as x

niter = 20
verbose = True
d = x.shape[1]
for k in k_test:
    kmn_model = faiss.Kmeans(d, k, niter=niter, verbose=verbose)
    kmn_model.train(x)
    D, I = kmn_model.index.search(x, 1)
    Sum_of_squared_distances.append(sum(D))

# Shot k method graph
plt.plot(k_test, Sum_of_squared_distances, 'bx-')
plt.xlabel('k')
plt.ylabel('Sum of squared distances')
plt.title('Elbow Method For Optimal k')
plt.show()
# Out:
# WARNING clustering 13 points to 2 centroids: please provide at least 78 training points
# WARNING clustering 13 points to 3 centroids: please provide at least 117 training points
# WARNING clustering 13 points to 4 centroids: please provide at least 156 training points
# WARNING clustering 13 points to 5 centroids: please provide at least 195 training points
# WARNING clustering 13 points to 6 centroids: please provide at least 234 training points
# WARNING clustering 13 points to 7 centroids: please provide at least 273 training points
# WARNING clustering 13 points to 8 centroids: please provide at least 312 training points
# WARNING clustering 13 points to 9 centroids: please provide at least 351 training points
# WARNING clustering 13 points to 10 centroids: please provide at least 390 training points
# WARNING clustering 13 points to 11 centroids: please provide at least 429 training points
# WARNING clustering 13 points to 12 centroids: please provide at least 468 training points
# Clustering 13 points in 74D to 2 clusters, redo 1 times, 20 iterations
#   Preprocessing in 0.00 s
#   Iteration 19 (0.00 s, search 0.00 s): objective=400134 imbalance=1.290 nsplit=0
# Clustering 13 points in 74D to 3 clusters, redo 1 times, 20 iterations
#   Preprocessing in 0.00 s
#   Iteration 19 (0.00 s, search 0.00 s): objective=220116 imbalance=1.225 nsplit=0
# Clustering 13 points in 74D to 4 clusters, redo 1 times, 20 iterations
#   Preprocessing in 0.00 s
#   Iteration 19 (0.00 s, search 0.00 s): objective=160668 imbalance=1.349 nsplit=0
# Clustering 13 points in 74D to 5 clusters, redo 1 times, 20 iterations
#   Preprocessing in 0.00 s
#   Iteration 19 (0.00 s, search 0.00 s): objective=145013 imbalance=1.213 nsplit=0
# Clustering 13 points in 74D to 6 clusters, redo 1 times, 20 iterations
#   Preprocessing in 0.00 s
#   Iteration 19 (0.00 s, search 0.00 s): objective=102612 imbalance=1.101 nsplit=0
# Clustering 13 points in 74D to 7 clusters, redo 1 times, 20 iterations
#   Preprocessing in 0.00 s
#   Iteration 19 (0.00 s, search 0.00 s): objective=96153.7 imbalance=1.118 nsplit=0
# Clustering 13 points in 74D to 8 clusters, redo 1 times, 20 iterations
#   Preprocessing in 0.00 s
#   Iteration 19 (0.00 s, search 0.00 s): objective=36646.4 imbalance=1.183 nsplit=0
# Clustering 13 points in 74D to 9 clusters, redo 1 times, 20 iterations
#   Preprocessing in 0.00 s
#   Iteration 19 (0.00 s, search 0.00 s): objective=34387.1 imbalance=1.225 nsplit=0
# Clustering 13 points in 74D to 10 clusters, redo 1 times, 20 iterations
#   Preprocessing in 0.00 s
#   Iteration 19 (0.00 s, search 0.00 s): objective=23121.8 imbalance=1.124 nsplit=0
# Clustering 13 points in 74D to 11 clusters, redo 1 times, 20 iterations
#   Preprocessing in 0.00 s
#   Iteration 19 (0.00 s, search 0.00 s): objective=13886.8 imbalance=1.107 nsplit=0
# Clustering 13 points in 74D to 12 clusters, redo 1 times, 20 iterations
#   Preprocessing in 0.00 s
#   Iteration 19 (0.00 s, search 0.00 s): objective=7068.91 imbalance=1.065 nsplit=0

# %%
# Determine best iteration for clustering (check range from 10 to 50)

# Compile inertia values
Sum_of_squared_distances = []
i_test = range(0,50)

x = data_to_clusters.copy(order='C') # define datasets as x

k = 4 # from previous test
verbose = True
d = x.shape[1]
for i in i_test:
    kmn_model = faiss.Kmeans(d, k, niter=i, verbose=verbose)
    kmn_model.train(x)
    D, I = kmn_model.index.search(x, 1)
    Sum_of_squared_distances.append(sum(D))

# Shot k method graph
plt.plot(i_test, Sum_of_squared_distances, 'bx-')
plt.xlabel('iter')
plt.ylabel('Sum of squared distances')
plt.title('Elbow Method For Optimal k')
plt.show()
# Out:
# WARNING clustering 13 points to 4 centroids: please provide at least 156 training points
# WARNING clustering 13 points to 4 centroids: please provide at least 156 training points
# WARNING clustering 13 points to 4 centroids: please provide at least 156 training points
# WARNING clustering 13 points to 4 centroids: please provide at least 156 training points
# WARNING clustering 13 points to 4 centroids: please provide at least 156 training points
# WARNING clustering 13 points to 4 centroids: please provide at least 156 training points
# WARNING clustering 13 points to 4 centroids: please provide at least 156 training points
# WARNING clustering 13 points to 4 centroids: please provide at least 156 training points
# WARNING clustering 13 points to 4 centroids: please provide at least 156 training points
# WARNING clustering 13 points to 4 centroids: please provide at least 156 training points
# WARNING clustering 13 points to 4 centroids: please provide at least 156 training points
# WARNING clustering 13 points to 4 centroids: please provide at least 156 training points
# WARNING clustering 13 points to 4 centroids: please provide at least 156 training points
# WARNING clustering 13 points to 4 centroids: please provide at least 156 training points
# WARNING clustering 13 points to 4 centroids: please provide at least 156 training points
# WARNING clustering 13 points to 4 centroids: please provide at least 156 training points
# WARNING clustering 13 points to 4 centroids: please provide at least 156 training points
# WARNING clustering 13 points to 4 centroids: please provide at least 156 training points
# WARNING clustering 13 points to 4 centroids: please provide at least 156 training points
# WARNING clustering 13 points to 4 centroids: please provide at least 156 training points
# WARNING clustering 13 points to 4 centroids: please provide at least 156 training points
# WARNING clustering 13 points to 4 centroids: please provide at least 156 training points
# WARNING clustering 13 points to 4 centroids: please provide at least 156 training points
# WARNING clustering 13 points to 4 centroids: please provide at least 156 training points
# WARNING clustering 13 points to 4 centroids: please provide at least 156 training points
# WARNING clustering 13 points to 4 centroids: please provide at least 156 training points
# WARNING clustering 13 points to 4 centroids: please provide at least 156 training points
# WARNING clustering 13 points to 4 centroids: please provide at least 156 training points
# WARNING clustering 13 points to 4 centroids: please provide at least 156 training points
# WARNING clustering 13 points to 4 centroids: please provide at least 156 training points
# WARNING clustering 13 points to 4 centroids: please provide at least 156 training points
# WARNING clustering 13 points to 4 centroids: please provide at least 156 training points
# WARNING clustering 13 points to 4 centroids: please provide at least 156 training points
# WARNING clustering 13 points to 4 centroids: please provide at least 156 training points
# WARNING clustering 13 points to 4 centroids: please provide at least 156 training points
# WARNING clustering 13 points to 4 centroids: please provide at least 156 training points
# WARNING clustering 13 points to 4 centroids: please provide at least 156 training points
# WARNING clustering 13 points to 4 centroids: please provide at least 156 training points
# WARNING clustering 13 points to 4 centroids: please provide at least 156 training points
# WARNING clustering 13 points to 4 centroids: please provide at least 156 training points
# WARNING clustering 13 points to 4 centroids: please provide at least 156 training points
# WARNING clustering 13 points to 4 centroids: please provide at least 156 training points
# WARNING clustering 13 points to 4 centroids: please provide at least 156 training points
# WARNING clustering 13 points to 4 centroids: please provide at least 156 training points
# WARNING clustering 13 points to 4 centroids: please provide at least 156 training points
# WARNING clustering 13 points to 4 centroids: please provide at least 156 training points
# WARNING clustering 13 points to 4 centroids: please provide at least 156 training points
# WARNING clustering 13 points to 4 centroids: please provide at least 156 training points
# WARNING clustering 13 points to 4 centroids: please provide at least 156 training points
# WARNING clustering 13 points to 4 centroids: please provide at least 156 training points
# Clustering 13 points in 74D to 4 clusters, redo 1 times, 0 iterations
#   Preprocessing in 0.00 s
#
# Clustering 13 points in 74D to 4 clusters, redo 1 times, 1 iterations
#   Preprocessing in 0.00 s
#   Iteration 0 (0.00 s, search 0.00 s): objective=549587 imbalance=1.302 nsplit=0
# Clustering 13 points in 74D to 4 clusters, redo 1 times, 2 iterations
#   Preprocessing in 0.00 s
#   Iteration 1 (0.00 s, search 0.00 s): objective=317134 imbalance=1.207 nsplit=0
# Clustering 13 points in 74D to 4 clusters, redo 1 times, 3 iterations
#   Preprocessing in 0.00 s
#   Iteration 2 (0.00 s, search 0.00 s): objective=197059 imbalance=1.349 nsplit=0
# Clustering 13 points in 74D to 4 clusters, redo 1 times, 4 iterations
#   Preprocessing in 0.00 s
#   Iteration 3 (0.00 s, search 0.00 s): objective=160668 imbalance=1.349 nsplit=0
# Clustering 13 points in 74D to 4 clusters, redo 1 times, 5 iterations
#   Preprocessing in 0.00 s
#   Iteration 4 (0.00 s, search 0.00 s): objective=160668 imbalance=1.349 nsplit=0
# Clustering 13 points in 74D to 4 clusters, redo 1 times, 6 iterations
#   Preprocessing in 0.00 s
#   Iteration 5 (0.00 s, search 0.00 s): objective=160668 imbalance=1.349 nsplit=0
# Clustering 13 points in 74D to 4 clusters, redo 1 times, 7 iterations
#   Preprocessing in 0.00 s
#   Iteration 6 (0.00 s, search 0.00 s): objective=160668 imbalance=1.349 nsplit=0
# Clustering 13 points in 74D to 4 clusters, redo 1 times, 8 iterations
#   Preprocessing in 0.00 s
#   Iteration 7 (0.00 s, search 0.00 s): objective=160668 imbalance=1.349 nsplit=0
# Clustering 13 points in 74D to 4 clusters, redo 1 times, 9 iterations
#   Preprocessing in 0.00 s
#   Iteration 8 (0.00 s, search 0.00 s): objective=160668 imbalance=1.349 nsplit=0
# Clustering 13 points in 74D to 4 clusters, redo 1 times, 10 iterations
#   Preprocessing in 0.00 s
#   Iteration 9 (0.00 s, search 0.00 s): objective=160668 imbalance=1.349 nsplit=0
# Clustering 13 points in 74D to 4 clusters, redo 1 times, 11 iterations
#   Preprocessing in 0.00 s
#   Iteration 10 (0.00 s, search 0.00 s): objective=160668 imbalance=1.349 nsplit=0
# Clustering 13 points in 74D to 4 clusters, redo 1 times, 12 iterations
#   Preprocessing in 0.00 s
#   Iteration 11 (0.00 s, search 0.00 s): objective=160668 imbalance=1.349 nsplit=0
# Clustering 13 points in 74D to 4 clusters, redo 1 times, 13 iterations
#   Preprocessing in 0.00 s
#   Iteration 12 (0.00 s, search 0.00 s): objective=160668 imbalance=1.349 nsplit=0
# Clustering 13 points in 74D to 4 clusters, redo 1 times, 14 iterations
#   Preprocessing in 0.00 s
#   Iteration 13 (0.00 s, search 0.00 s): objective=160668 imbalance=1.349 nsplit=0
# Clustering 13 points in 74D to 4 clusters, redo 1 times, 15 iterations
#   Preprocessing in 0.00 s
#   Iteration 14 (0.00 s, search 0.00 s): objective=160668 imbalance=1.349 nsplit=0
# Clustering 13 points in 74D to 4 clusters, redo 1 times, 16 iterations
#   Preprocessing in 0.00 s
#   Iteration 15 (0.00 s, search 0.00 s): objective=160668 imbalance=1.349 nsplit=0
# Clustering 13 points in 74D to 4 clusters, redo 1 times, 17 iterations
#   Preprocessing in 0.00 s
#   Iteration 16 (0.00 s, search 0.00 s): objective=160668 imbalance=1.349 nsplit=0
# Clustering 13 points in 74D to 4 clusters, redo 1 times, 18 iterations
#   Preprocessing in 0.00 s
#   Iteration 17 (0.00 s, search 0.00 s): objective=160668 imbalance=1.349 nsplit=0
# Clustering 13 points in 74D to 4 clusters, redo 1 times, 19 iterations
#   Preprocessing in 0.00 s
#   Iteration 18 (0.00 s, search 0.00 s): objective=160668 imbalance=1.349 nsplit=0
# Clustering 13 points in 74D to 4 clusters, redo 1 times, 20 iterations
#   Preprocessing in 0.00 s
#   Iteration 19 (0.01 s, search 0.00 s): objective=160668 imbalance=1.349 nsplit=0
# Clustering 13 points in 74D to 4 clusters, redo 1 times, 21 iterations
#   Preprocessing in 0.00 s
#   Iteration 20 (0.00 s, search 0.00 s): objective=160668 imbalance=1.349 nsplit=0
# Clustering 13 points in 74D to 4 clusters, redo 1 times, 22 iterations
#   Preprocessing in 0.00 s
#   Iteration 21 (0.01 s, search 0.00 s): objective=160668 imbalance=1.349 nsplit=0
# Clustering 13 points in 74D to 4 clusters, redo 1 times, 23 iterations
#   Preprocessing in 0.00 s
#   Iteration 22 (0.01 s, search 0.00 s): objective=160668 imbalance=1.349 nsplit=0
# Clustering 13 points in 74D to 4 clusters, redo 1 times, 24 iterations
#   Preprocessing in 0.00 s
#   Iteration 23 (0.00 s, search 0.00 s): objective=160668 imbalance=1.349 nsplit=0
# Clustering 13 points in 74D to 4 clusters, redo 1 times, 25 iterations
#   Preprocessing in 0.00 s
#   Iteration 24 (0.00 s, search 0.00 s): objective=160668 imbalance=1.349 nsplit=0
# Clustering 13 points in 74D to 4 clusters, redo 1 times, 26 iterations
#   Preprocessing in 0.00 s
#   Iteration 25 (0.00 s, search 0.00 s): objective=160668 imbalance=1.349 nsplit=0
# Clustering 13 points in 74D to 4 clusters, redo 1 times, 27 iterations
#   Preprocessing in 0.00 s
#   Iteration 26 (0.00 s, search 0.00 s): objective=160668 imbalance=1.349 nsplit=0
# Clustering 13 points in 74D to 4 clusters, redo 1 times, 28 iterations
#   Preprocessing in 0.00 s
#   Iteration 27 (0.00 s, search 0.00 s): objective=160668 imbalance=1.349 nsplit=0
# Clustering 13 points in 74D to 4 clusters, redo 1 times, 29 iterations
#   Preprocessing in 0.00 s
#   Iteration 28 (0.00 s, search 0.00 s): objective=160668 imbalance=1.349 nsplit=0
# Clustering 13 points in 74D to 4 clusters, redo 1 times, 30 iterations
#   Preprocessing in 0.00 s
#   Iteration 29 (0.00 s, search 0.00 s): objective=160668 imbalance=1.349 nsplit=0
# Clustering 13 points in 74D to 4 clusters, redo 1 times, 31 iterations
#   Preprocessing in 0.00 s
#   Iteration 30 (0.00 s, search 0.00 s): objective=160668 imbalance=1.349 nsplit=0
# Clustering 13 points in 74D to 4 clusters, redo 1 times, 32 iterations
#   Preprocessing in 0.00 s
#   Iteration 31 (0.00 s, search 0.00 s): objective=160668 imbalance=1.349 nsplit=0
# Clustering 13 points in 74D to 4 clusters, redo 1 times, 33 iterations
#   Preprocessing in 0.00 s
#   Iteration 32 (0.01 s, search 0.00 s): objective=160668 imbalance=1.349 nsplit=0
# Clustering 13 points in 74D to 4 clusters, redo 1 times, 34 iterations
#   Preprocessing in 0.00 s
#   Iteration 33 (0.01 s, search 0.01 s): objective=160668 imbalance=1.349 nsplit=0
# Clustering 13 points in 74D to 4 clusters, redo 1 times, 35 iterations
#   Preprocessing in 0.00 s
#   Iteration 34 (0.00 s, search 0.00 s): objective=160668 imbalance=1.349 nsplit=0
# Clustering 13 points in 74D to 4 clusters, redo 1 times, 36 iterations
#   Preprocessing in 0.00 s
#   Iteration 35 (0.00 s, search 0.00 s): objective=160668 imbalance=1.349 nsplit=0
# Clustering 13 points in 74D to 4 clusters, redo 1 times, 37 iterations
#   Preprocessing in 0.00 s
#   Iteration 36 (0.00 s, search 0.00 s): objective=160668 imbalance=1.349 nsplit=0
# Clustering 13 points in 74D to 4 clusters, redo 1 times, 38 iterations
#   Preprocessing in 0.00 s
#   Iteration 37 (0.00 s, search 0.00 s): objective=160668 imbalance=1.349 nsplit=0
# Clustering 13 points in 74D to 4 clusters, redo 1 times, 39 iterations
#   Preprocessing in 0.00 s
#   Iteration 38 (0.00 s, search 0.00 s): objective=160668 imbalance=1.349 nsplit=0
# Clustering 13 points in 74D to 4 clusters, redo 1 times, 40 iterations
#   Preprocessing in 0.00 s
#   Iteration 39 (0.00 s, search 0.00 s): objective=160668 imbalance=1.349 nsplit=0
# Clustering 13 points in 74D to 4 clusters, redo 1 times, 41 iterations
#   Preprocessing in 0.00 s
#   Iteration 40 (0.00 s, search 0.00 s): objective=160668 imbalance=1.349 nsplit=0
# Clustering 13 points in 74D to 4 clusters, redo 1 times, 42 iterations
#   Preprocessing in 0.00 s
#   Iteration 41 (0.00 s, search 0.00 s): objective=160668 imbalance=1.349 nsplit=0
# Clustering 13 points in 74D to 4 clusters, redo 1 times, 43 iterations
#   Preprocessing in 0.00 s
#   Iteration 42 (0.00 s, search 0.00 s): objective=160668 imbalance=1.349 nsplit=0
# Clustering 13 points in 74D to 4 clusters, redo 1 times, 44 iterations
#   Preprocessing in 0.00 s
#   Iteration 43 (0.00 s, search 0.00 s): objective=160668 imbalance=1.349 nsplit=0
# Clustering 13 points in 74D to 4 clusters, redo 1 times, 45 iterations
#   Preprocessing in 0.00 s
#   Iteration 44 (0.00 s, search 0.00 s): objective=160668 imbalance=1.349 nsplit=0
# Clustering 13 points in 74D to 4 clusters, redo 1 times, 46 iterations
#   Preprocessing in 0.00 s
#   Iteration 45 (0.00 s, search 0.00 s): objective=160668 imbalance=1.349 nsplit=0
# Clustering 13 points in 74D to 4 clusters, redo 1 times, 47 iterations
#   Preprocessing in 0.00 s
#   Iteration 46 (0.00 s, search 0.00 s): objective=160668 imbalance=1.349 nsplit=0
# Clustering 13 points in 74D to 4 clusters, redo 1 times, 48 iterations
#   Preprocessing in 0.00 s
#   Iteration 47 (0.00 s, search 0.00 s): objective=160668 imbalance=1.349 nsplit=0
# Clustering 13 points in 74D to 4 clusters, redo 1 times, 49 iterations
#   Preprocessing in 0.00 s
#   Iteration 48 (0.00 s, search 0.00 s): objective=160668 imbalance=1.349 nsplit=0

# %%
# Determine best verbose for clustering

# Compile inertia values
Sum_of_squared_distances = []
v_test = [False, True]

x = data_to_clusters.copy(order='C') # define datasets as x

k = 4 # from previous test
niter = 10 # from previous test
d = x.shape[1]
for v in v_test:
    kmn_model = faiss.Kmeans(d, k, niter=niter, verbose=v)
    kmn_model.train(x)
    D, I = kmn_model.index.search(x, 1)
    Sum_of_squared_distances.append(sum(D))

# Shot k method graph
plt.plot(v_test, Sum_of_squared_distances, 'bx-')
plt.xlabel('verbose')
plt.ylabel('Sum of squared distances')
plt.title('Elbow Method For Optimal k')
plt.show()
# Out:
# Clustering 13 points in 74D to 4 clusters, redo 1 times, 10 iterations
#   Preprocessing in 0.00 s
#   Iteration 9 (0.00 s, search 0.00 s): objective=160668 imbalance=1.349 nsplit=0
# WARNING clustering 13 points to 4 centroids: please provide at least 156 training points
# WARNING clustering 13 points to 4 centroids: please provide at least 156 training points

# %%
# Train K-Means model
x = data_to_clusters.copy(order='C') # define datasets as x

ncentroids = 4
niter = 10
verbose = True
d = x.shape[1]
kmn_model = faiss.Kmeans(d, ncentroids, niter=niter, verbose=verbose)
kmn_model.train(x)
# Out:
# Clustering 13 points in 74D to 4 clusters, redo 1 times, 10 iterations
#   Preprocessing in 0.00 s
#   Iteration 9 (0.00 s, search 0.00 s): objective=160668 imbalance=1.349 nsplit=0
# WARNING clustering 13 points to 4 centroids: please provide at least 156 training points
# 160667.734375

# %%
# Assign clustering result
D, I = kmn_model.index.search(x, 1)

df['kmn_clusters'] = I

# %%
plt.scatter(df['threshold_yield'],
            df['loss_calculation'],
            c=df['kmn_clusters']
            ,cmap='rainbow')
plt.title("Loss Calculation Values")
plt.xlabel("Threshold Yield")
plt.ylabel("Loss Calculation")
# Out:
# Text(0, 0.5, 'Loss Calculation')

# %% [markdown]
# <h5>Method 2 - Agglomerative Hierarchical Clustering</h5>

# %%
# Import necessary modules
import scipy.cluster.hierarchy as shc
from sklearn.cluster import AgglomerativeClustering

# %%
# Create overall dendogram
plt.figure(figsize=(100, 10))
plt.title("Loss alculation Dendograms")
dend = shc.dendrogram(shc.linkage(x, method='ward'))

plt.axhline(y=max(D), color='r', linestyle='--')

# %%
# Train and assign cluster to dataset
shc_model = AgglomerativeClustering(n_clusters=4, affinity='euclidean', linkage='ward')

df['shc_clusters'] = shc_model.fit_predict(x)

# %%
plt.scatter(df['threshold_yield'],
            df['loss_calculation'],
            c=df['shc_clusters']
            ,cmap='rainbow')
plt.title("Loss Calculation Values")
plt.xlabel("Threshold Yield")
plt.ylabel("Loss Calculation")
# Out:
# Text(0, 0.5, 'Loss Calculation')

# %% [markdown]
# <h5>Method 3 - Density-Based Spatial Clustering of Applications with Noise (DBSCAN)</h5>

# %%
# Import necessary modules
from sklearn.neighbors import NearestNeighbors
from sklearn.cluster import DBSCAN

# %% [markdown]
# For 2-dimensional data, use DBSCAN’s default value of MinPts = 4 (Ester et al., 1996).
# <br/>
# <i>source: https://medium.com/@tarammullin/dbscan-parameter-estimation-ff8330e3a3bd</i>

# %%
# Train model for epsilon optimisation
neighbors = NearestNeighbors(n_neighbors=4)
neighbors_fit = neighbors.fit(x)
distances, indices = neighbors_fit.kneighbors(x)

# %%
# Get distances for epsilon optimasion
distances = np.sort(distances, axis=0)
distances = distances[:,1]
plt.plot(distances)

# %%
# Zoom in to elbow
plt.xlim([8,12])
plt.plot(distances)

# %%
# Train model for dataset and assign cluster to dataset
dbs_model = DBSCAN(eps=1/9, min_samples=4).fit(x)
df['dbs_clusters'] = dbs_model.labels_

# %%
plt.scatter(df['threshold_yield'],
            df['loss_calculation'],
            c=df['dbs_clusters']
            ,cmap='rainbow')
plt.title("Loss Calculation Values")
plt.xlabel("Threshold Yield")
plt.ylabel("Loss Calculation")
# Out:
# Text(0, 0.5, 'Loss Calculation')

# %% [markdown]
# <h5>Method 4 - Mean-Shift Clustering</h5>

# %%
# Import necessary modules
from sklearn.cluster import MeanShift, estimate_bandwidth

# %%
# Train model for dataset and assign cluster to dataset
bandwidth = estimate_bandwidth(x)
msc_model = MeanShift(bandwidth=bandwidth).fit(x)
df['msc_clusters'] = msc_model.labels_

# %%
plt.scatter(df['threshold_yield'],
            df['loss_calculation'],
            c=df['msc_clusters']
            ,cmap='rainbow')
plt.title("Loss Calculation Values")
plt.xlabel("Threshold Yield")
plt.ylabel("Loss Calculation")
# Out:
# Text(0, 0.5, 'Loss Calculation')

# %% [markdown]
# <h3>Chapter 3: Model evaluation</h3>
# <p>This chapter explains the evaluation of models for the dataset and determine the best model to cluster the dataset. The choosen model will be applied across dataset with the same hyperparameters for consistency. To evaluate the model, we will use Davies Bouldin Index.</p>
# <p>Please note that this chapter does not include the analysis of each cluster and definition to business context. Those analyses will be performed on the latter chapters.</p>

# %%
df
# Out:
#                 ID  threshold_yield  loss_calculation  \
# 0   andhra pradesh     3.426360e-02          0.123862
# 1            bihar     1.157366e-03          0.066997
# 3          gujarat     1.358426e-03          0.828425
# 4          haryana     1.196733e-05          0.402583
# 5        jharkhand     5.422482e-07          0.036091
# 6        karnataka     8.494067e-03          0.234062
# 7   madhya pradesh     1.884336e-02          0.359120
# 8      maharashtra     5.488456e-03          0.456289
# 9           odisha     6.565758e-03          0.330579
# 10       rajasthan     1.637262e-01          1.000000
# 11       telangana     2.259635e-02          0.134130
# 12   uttar pradesh     1.000000e+00          0.480933
# 14     west bengal     1.258870e-03          0.172408
#
#     Average Temperature January (C)  Average Temperature February (C)  \
# 0                         23.411857                         25.271789
# 1                         16.280698                         19.919493
# 3                         20.792321                         23.090539
# 4                         13.091340                         16.452165
# 5                         16.501022                         20.377710
# 6                         22.579367                         24.696755
# 7                         17.658561                         21.061639
# 8                         21.947628                         24.646489
# 9                         20.509336                         23.893078
# 10                        15.533123                         19.018723
# 11                        22.884843                         25.631368
# 12                        14.915361                         18.548858
# 14                        17.951215                         21.496232
#
#     Average Temperature March (C)  Average Temperature April (C)  \
# 0                       27.999885                      30.148904
# 1                       25.442108                      29.990418
# 3                       27.060659                      30.396527
# 4                       22.179794                      28.866186
# 5                       25.257873                      29.727607
# 6                       27.218227                      28.565376
# 7                       25.970414                      31.133293
# 8                       28.021386                      31.455692
# 9                       27.665558                      30.467272
# 10                      24.740967                      30.523307
# 11                      28.818600                      31.711993
# 12                      24.234219                      30.171192
# 14                      26.018047                      29.002198
#
#     Average Temperature May (C)  Average Temperature June (C)  \
# 0                     31.837487                     30.353446
# 1                     30.853114                     30.251034
# 3                     31.672581                     30.535144
# 4                     32.730928                     33.131546
# 5                     30.845399                     29.263804
# 6                     27.957004                     24.902590
# 7                     33.617598                     30.854250
# 8                     32.286505                     28.343365
# 9                     31.567120                     29.467542
# 10                    33.808936                     33.191863
# 11                    33.382652                     29.502701
# 12                    32.744281                     32.269585
# 14                    29.525632                     28.972021
#
#     Average Temperature July (C)  ...  Average Sun Hours July  \
# 0                      28.796120  ...               10.284060
# 1                      28.436810  ...               10.311333
# 3                      27.747799  ...               35.409351
# 4                      30.285567  ...                9.940619
# 5                      26.635787  ...               39.297794
# 6                      23.680814  ...               24.481854
# 7                      26.384748  ...               19.854143
# 8                      25.397805  ...                7.137453
# 9                      27.138528  ...              168.537587
# 10                     29.723572  ...               20.280280
# 11                     26.762558  ...               92.934153
# 12                     28.955590  ...               14.332583
# 14                     27.791902  ...               29.373492
#
#     Average Sun Hours August  Average Sun Hours September  \
# 0                   9.820451                     9.295170
# 1                  10.300870                    10.357100
# 3                  34.085937                    42.319218
# 4                   9.525155                     9.663093
# 5                  38.692279                    39.216728
# 6                  25.948928                    26.687692
# 7                  18.977953                    24.153746
# 8                   6.698044                     7.509409
# 9                 175.077087                   173.894452
# 10                 18.885318                    20.898991
# 11                 94.812383                    96.449244
# 12                 13.858660                    14.306262
# 14                 30.051604                    30.078127
#
#     Average Sun Hours October  Average Sun Hours November  \
# 0                    8.700717                    8.395947
# 1                   11.431295                   11.610803
# 3                   51.403038                   49.851547
# 4                   10.118969                    9.517320
# 5                   43.334926                   44.198713
# 6                   30.095805                   29.173413
# 7                   29.471798                   28.828312
# 8                    9.365783                    9.595219
# 9                  183.296120                  178.920893
# 10                  22.419238                   21.403640
# 11                 106.195699                  101.550169
# 12                  16.014616                   15.901789
# 14                  32.460875                   33.314259
#
#     Average Sun Hours December  kmn_clusters  shc_clusters  dbs_clusters  \
# 0                     8.165693             1             2            -1
# 1                    10.940318             2             1            -1
# 3                    51.215680             2             1            -1
# 4                     8.749897             1             2            -1
# 5                    44.923529             2             1            -1
# 6                    31.553485             1             2            -1
# 7                    29.317925             2             1            -1
# 8                     9.565708             2             1            -1
# 9                   188.246091             0             0            -1
# 10                   21.415255             1             2            -1
# 11                  109.749804             0             0            -1
# 12                   15.280632             2             1            -1
# 14                   33.795012             3             3            -1
#
#     msc_clusters
# 0              0
# 1              0
# 3              0
# 4              0
# 5              0
# 6              0
# 7              0
# 8              0
# 9              2
# 10             0
# 11             1
# 12             0
# 14             3
#
# [13 rows x 79 columns]

# %%
for cluster in ['kmn', 'shc', 'dbs', 'msc']:
    try:
        score = metrics.davies_bouldin_score(x, df[cluster+'_clusters'])
        print(cluster, '> # of clusters:', len(df[cluster+'_clusters'].unique()), '| DBI:', score)
    except:
        pass
# Out:
# kmn > # of clusters: 4 | DBI: 0.7336348089774103
# shc > # of clusters: 4 | DBI: 0.7336348089774103
# msc > # of clusters: 4 | DBI: 0.4093589998867264

# %%
# Export csv before clustering for performance improvement
df.to_csv("datasets_clustered/state_kharif_clustered_done.csv", sep=';')

# %%
# Export selected model
model = shc_model
pickle.dump(model, open("clustering_models/model_kharif_states.pkl", "wb"))
