# %% [markdown]
# <img src = "https://escp.eu/sites/default/files/logo/ESCP-logo-white-misalign.svg" width = 400 style="background-color: #240085;">
# <h1 align=center><font size = 6>ESCP Business School</font></h1>
# <h3 align=center><font size = 5>SCOR Datathon</font><br/>
# <font size = 3>The Data Science Challenge Bridging Indian Agricultureal Protection Gap</font></h3>
# <h6 align=center>Chapter 3B - Analysis to Clustering Methods (Rabi - Free Level)</h6>

# %% [markdown]
# Last Updated: December 09, 2021\
# Author: Group 21 - Anniek Brink, Jeanne Dubois, and Resha Dirga

# %% [markdown]
# <h3>Chapter Objectives</h3>
#
# <p>This chapter aims to define the best clustering methods to use for the datasets. There are <b><u>four</u></b> methods that we are going to test on this chapter:</p>
#
# <ul>
#     <li>KMeans Clustering</li>
#     <li>Agglomerative Hierarchical Clustering</li>
#     <li>Density-Based Spatial Clustering of Applications with Noise (DBSCAN)</li>
#     <li>Mean-Shift Clustering</li>
# </ul>
#
# <b><i>Source:</i></b> <a href="https://towardsdatascience.com/the-5-clustering-algorithms-data-scientists-need-to-know-a36d136ef68">https://towardsdatascience.com/the-5-clustering-algorithms-data-scientists-need-to-know-a36d136ef68</a>

# %% [markdown]
# <h3>Chapter 1: Import modules</h3>
# <p>This chapter lists all modules that being used on this document. The module import process will be performed on this chapter</p>

# %%
import numpy as np
import pandas as pd

from sklearn import metrics

import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
import pickle

# %% [markdown]
# <h3>Chapter 2: Data Loading and Initial Plotting</h3>
# <p>This chapter reads the data and provides a scatter plot as an initial overview. The chapter also gives an overview of value distribution using a histogram</p>

# %%
filename = "datasets_preprocessed/df_rabi_preprocessed_to_cluster.csv"

# %%
df = pd.read_csv(filename, delimiter=";", index_col = 0)

# %%
df = df.dropna(axis=1, how='all')
df = df.dropna()
data_to_clusters = df.drop(columns=['ID'])

# %%
# View datapoints on plot charts

plt.scatter(df['threshold_yield'], df['loss_calculation'])
plt.title("Loss Calculation Values")
plt.xlabel("Threshold Yield")
plt.ylabel("Loss Calculation")
plt.show()

# %%
plt.hist(df['loss_calculation'], density=False, bins=1000)  # density=False would make counts
plt.ylabel('Frequency')
plt.xlabel('Loss Calculation');

# %% [markdown]
# <h3>Chapter 3: Modelling</h3>
# <p>This chapter define and compile the model, incuding choosing the best hyperparameters for the model. This chapter will test several model and determine the best models based on analysis.
# </p>

# %% [markdown]
# <h5>Method 1 - KMeans Clustering</h5>

# %%
# Import necessary modules
import faiss

# %%
data_to_clusters = data_to_clusters.to_numpy().astype(np.float32)

# %%
# Determine best k for clustering (check range from 1 to 10)

# Compile inertia values
Sum_of_squared_distances = []
k_test = range(2,15)

x = data_to_clusters.copy(order='C') # define datasets as x

niter = 20
verbose = True
d = x.shape[1]
for k in k_test:
    kmn_model = faiss.Kmeans(d, k, niter=niter, verbose=verbose)
    kmn_model.train(x)
    D, I = kmn_model.index.search(x, 1)
    Sum_of_squared_distances.append(sum(D))

# Shot k method graph
plt.plot(k_test, Sum_of_squared_distances, 'bx-')
plt.xlabel('k')
plt.ylabel('Sum of squared distances')
plt.title('Elbow Method For Optimal k')
plt.show()
# Out:
# Clustering 488 points in 74D to 2 clusters, redo 1 times, 20 iterations
#   Preprocessing in 0.00 s
#   Iteration 19 (0.01 s, search 0.01 s): objective=2.01312e+07 imbalance=1.748 nsplit=0
# Clustering 488 points in 74D to 3 clusters, redo 1 times, 20 iterations
#   Preprocessing in 0.00 s
#   Iteration 19 (0.01 s, search 0.01 s): objective=1.45915e+07 imbalance=1.416 nsplit=0
# Clustering 488 points in 74D to 4 clusters, redo 1 times, 20 iterations
#   Preprocessing in 0.00 s
#   Iteration 19 (0.00 s, search 0.00 s): objective=1.37228e+07 imbalance=1.657 nsplit=0
# Clustering 488 points in 74D to 5 clusters, redo 1 times, 20 iterations
#   Preprocessing in 0.00 s
#   Iteration 19 (0.00 s, search 0.00 s): objective=7.93623e+06 imbalance=2.085 nsplit=0
# Clustering 488 points in 74D to 6 clusters, redo 1 times, 20 iterations
#   Preprocessing in 0.00 s
#   Iteration 19 (0.00 s, search 0.00 s): objective=6.26931e+06 imbalance=1.725 nsplit=0
# Clustering 488 points in 74D to 7 clusters, redo 1 times, 20 iterations
#   Preprocessing in 0.00 s
#   Iteration 19 (0.01 s, search 0.00 s): objective=5.90380e+06 imbalance=1.810 nsplit=0
# Clustering 488 points in 74D to 8 clusters, redo 1 times, 20 iterations
#   Preprocessing in 0.00 s
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.60527e+06 imbalance=1.872 nsplit=0
# Clustering 488 points in 74D to 9 clusters, redo 1 times, 20 iterations
#   Preprocessing in 0.00 s
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.32003e+06 imbalance=1.485 nsplit=0
# Clustering 488 points in 74D to 10 clusters, redo 1 times, 20 iterations
#   Preprocessing in 0.00 s
#   Iteration 19 (0.01 s, search 0.01 s): objective=5.13983e+06 imbalance=1.365 nsplit=0
# Clustering 488 points in 74D to 11 clusters, redo 1 times, 20 iterations
#   Preprocessing in 0.00 s
#   Iteration 19 (0.01 s, search 0.01 s): objective=3.98294e+06 imbalance=1.477 nsplit=0
# Clustering 488 points in 74D to 12 clusters, redo 1 times, 20 iterations
#   Preprocessing in 0.00 s
#   Iteration 14 (0.00 s, search
# WARNING clustering 488 points to 13 centroids: please provide at least 507 training points
# WARNING clustering 488 points to 14 centroids: please provide at least 546 training points
#   Iteration 19 (0.01 s, search 0.00 s): objective=3.84307e+06 imbalance=1.468 nsplit=0
# Clustering 488 points in 74D to 13 clusters, redo 1 times, 20 iterations
#   Preprocessing in 0.00 s
#   Iteration 19 (0.01 s, search 0.00 s): objective=3.79898e+06 imbalance=1.521 nsplit=0
# Clustering 488 points in 74D to 14 clusters, redo 1 times, 20 iterations
#   Preprocessing in 0.00 s
#   Iteration 19 (0.00 s, search 0.00 s): objective=3.47514e+06 imbalance=1.413 nsplit=0

# %%
# Determine best iteration for clustering (check range from 10 to 50)

# Compile inertia values
Sum_of_squared_distances = []
i_test = range(0,50)

x = data_to_clusters.copy(order='C') # define datasets as x

k = 6 # from previous test
verbose = True
d = x.shape[1]
for i in i_test:
    kmn_model = faiss.Kmeans(d, k, niter=i, verbose=verbose)
    kmn_model.train(x)
    D, I = kmn_model.index.search(x, 1)
    Sum_of_squared_distances.append(sum(D))

# Shot k method graph
plt.plot(i_test, Sum_of_squared_distances, 'bx-')
plt.xlabel('iter')
plt.ylabel('Sum of squared distances')
plt.title('Elbow Method For Optimal k')
plt.show()
# Out:
# Clustering 488 points in 74D to 6 clusters, redo 1 times, 0 iterations
#   Preprocessing in 0.00 s
#
# Clustering 488 points in 74D to 6 clusters, redo 1 times, 1 iterations
#   Preprocessing in 0.00 s
#   Iteration 0 (0.00 s, search 0.00 s): objective=1.65907e+07 imbalance=1.320 nsplit=0
# Clustering 488 points in 74D to 6 clusters, redo 1 times, 2 iterations
#   Preprocessing in 0.00 s
#   Iteration 1 (0.00 s, search 0.00 s): objective=9.80872e+06 imbalance=1.430 nsplit=0
# Clustering 488 points in 74D to 6 clusters, redo 1 times, 3 iterations
#   Preprocessing in 0.00 s
#   Iteration 2 (0.00 s, search 0.00 s): objective=9.4919e+06 imbalance=1.516 nsplit=0
# Clustering 488 points in 74D to 6 clusters, redo 1 times, 4 iterations
#   Preprocessing in 0.00 s
#   Iteration 3 (0.00 s, search 0.00 s): objective=9.24913e+06 imbalance=1.593 nsplit=0
# Clustering 488 points in 74D to 6 clusters, redo 1 times, 5 iterations
#   Preprocessing in 0.00 s
#   Iteration 4 (0.00 s, search 0.00 s): objective=8.80416e+06 imbalance=1.438 nsplit=0
# Clustering 488 points in 74D to 6 clusters, redo 1 times, 6 iterations
#   Preprocessing in 0.00 s
#   Iteration 5 (0.00 s, search 0.00 s): objective=7.62147e+06 imbalance=1.534 nsplit=0
# Clustering 488 points in 74D to 6 clusters, redo 1 times, 7 iterations
#   Preprocessing in 0.00 s
#   Iteration 6 (0.00 s, search 0.00 s): objective=6.56738e+06 imbalance=1.565 nsplit=0
# Clustering 488 points in 74D to 6 clusters, redo 1 times, 8 iterations
#   Preprocessing in 0.00 s
#   Iteration 7 (0.00 s, search 0.00 s): objective=6.37089e+06 imbalance=1.624 nsplit=0
# Clustering 488 points in 74D to 6 clusters, redo 1 times, 9 iterations
#   Preprocessing in 0.00 s
#   Iteration 8 (0.00 s, search 0.00 s): objective=6.30376e+06 imbalance=1.682 nsplit=0
# Clustering 488 points in 74D to 6 clusters, redo 1 times, 10 iterations
#   Preprocessing in 0.00 s
#   Iteration 9 (0.00 s, search 0.00 s): objective=6.28246e+06 imbalance=1.711 nsplit=0
# Clustering 488 points in 74D to 6 clusters, redo 1 times, 11 iterations
#   Preprocessing in 0.00 s
#   Iteration 10 (0.00 s, search 0.00 s): objective=6.27737e+06 imbalance=1.729 nsplit=0
# Clustering 488 points in 74D to 6 clusters, redo 1 times, 12 iterations
#   Preprocessing in 0.00 s
#   Iteration 11 (0.00 s, search 0.00 s): objective=6.27225e+06 imbalance=1.725 nsplit=0
# Clustering 488 points in 74D to 6 clusters, redo 1 times, 13 iterations
#   Preprocessing in 0.00 s
#   Iteration 12 (0.00 s, search 0.00 s): objective=6.26931e+06 imbalance=1.725 nsplit=0
# Clustering 488 points in 74D to 6 clusters, redo 1 times, 14 iterations
#   Preprocessing in 0.00 s
#   Iteration 13 (0.00 s, search 0.00 s): objective=6.26931e+06 imbalance=1.725 nsplit=0
# Clustering 488 points in 74D to 6 clusters, redo 1 times, 15 iterations
#   Preprocessing in 0.00 s
#   Iteration 14 (0.00 s, search 0.00 s): objective=6.26931e+06 imbalance=1.725 nsplit=0
# Clustering 488 points in 74D to 6 clusters, redo 1 times, 16 iterations
#   Preprocessing in 0.00 s
#   Iteration 15 (0.00 s, search 0.00 s): objective=6.26931e+06 imbalance=1.725 nsplit=0
# Clustering 488 points in 74D to 6 clusters, redo 1 times, 17 iterations
#   Preprocessing in 0.00 s
#   Iteration 16 (0.00 s, search 0.00 s): objective=6.26931e+06 imbalance=1.725 nsplit=0
# Clustering 488 points in 74D to 6 clusters, redo 1 times, 18 iterations
#   Preprocessing in 0.00 s
#   Iteration 17 (0.00 s, search 0.00 s): objective=6.26931e+06 imbalance=1.725 nsplit=0
# Clustering 488 points in 74D to 6 clusters, redo 1 times, 19 iterations
#   Preprocessing in 0.00 s
#   Iteration 18 (0.00 s, search 0.00 s): objective=6.26931e+06 imbalance=1.725 nsplit=0
# Clustering 488 points in 74D to 6 clusters, redo 1 times, 20 iterations
#   Preprocessing in 0.00 s
#   Iteration 19 (0.01 s, search 0.01 s): objective=6.26931e+06 imbalance=1.725 nsplit=0
# Clustering 488 points in 74D to 6 clusters, redo 1 times, 21 iterations
#   Preprocessing in 0.00 s
#   Iteration 20 (0.01 s, search 0.01 s): objective=6.26931e+06 imbalance=1.725 nsplit=0
# Clustering 488 points in 74D to 6 clusters, redo 1 times, 22 iterations
#   Preprocessing in 0.00 s
#   Iteration 21 (0.01 s, search 0.01 s): objective=6.26931e+06 imbalance=1.725 nsplit=0
# Clustering 488 points in 74D to 6 clusters, redo 1 times, 23 iterations
#   Preprocessing in 0.00 s
#   Iteration 22 (0.00 s, search 0.00 s): objective=6.26931e+06 imbalance=1.725 nsplit=0
# Clustering 488 points in 74D to 6 clusters, redo 1 times, 24 iterations
#   Preprocessing in 0.00 s
#   Iteration 23 (0.00 s, search 0.00 s): objective=6.26931e+06 imbalance=1.725 nsplit=0
# Clustering 488 points in 74D to 6 clusters, redo 1 times, 25 iterations
#   Preprocessing in 0.00 s
#   Iteration 24 (0.00 s, search 0.00 s): objective=6.26931e+06 imbalance=1.725 nsplit=0
# Clustering 488 points in 74D to 6 clusters, redo 1 times, 26 iterations
#   Preprocessing in 0.00 s
#   Iteration 25 (0.00 s, search 0.00 s): objective=6.26931e+06 imbalance=1.725 nsplit=0
# Clustering 488 points in 74D to 6 clusters, redo 1 times, 27 iterations
#   Preprocessing in 0.00 s
#   Iteration 26 (0.00 s, search 0.00 s): objective=6.26931e+06 imbalance=1.725 nsplit=0
# Clustering 488 points in 74D to 6 clusters, redo 1 times, 28 iterations
#   Preprocessing in 0.00 s
#   Iteration 27 (0.01 s, search 0.01 s): objective=6.26931e+06 imbalance=1.725 nsplit=0
# Clustering 488 points in 74D to 6 clusters, redo 1 times, 29 iterations
#   Preprocessing in 0.00 s
#   Iteration 28 (0.01 s, search 0.01 s): objective=6.26931e+06 imbalance=1.725 nsplit=0
# Clustering 488 points in 74D to 6 clusters, redo 1 times, 30 iterations
#   Preprocessing in 0.00 s
#   Iteration 29 (0.01 s, search 0.00 s): objective=6.26931e+06 imbalance=1.725 nsplit=0
# Clustering 488 points in 74D to 6 clusters, redo 1 times, 31 iterations
#   Preprocessing in 0.00 s
#   Iteration 30 (0.01 s, search 0.00 s): objective=6.26931e+06 imbalance=1.725 nsplit=0
# Clustering 488 points in 74D to 6 clusters, redo 1 times, 32 iterations
#   Preprocessing in 0.00 s
#   Iteration 31 (0.01 s, search 0.00 s): objective=6.26931e+06 imbalance=1.725 nsplit=0
# Clustering 488 points in 74D to 6 clusters, redo 1 times, 33 iterations
#   Preprocessing in 0.00 s
#   Iteration 32 (0.01 s, search 0.00 s): objective=6.26931e+06 imbalance=1.725 nsplit=0
# Clustering 488 points in 74D to 6 clusters, redo 1 times, 34 iterations
#   Preprocessing in 0.00 s
#   Iteration 33 (0.01 s, search 0.01 s): objective=6.26931e+06 imbalance=1.725 nsplit=0
# Clustering 488 points in 74D to 6 clusters, redo 1 times, 35 iterations
#   Preprocessing in 0.00 s
#   Iteration 34 (0.01 s, search 0.01 s): objective=6.26931e+06 imbalance=1.725 nsplit=0
# Clustering 488 points in 74D to 6 clusters, redo 1 times, 36 iterations
#   Preprocessing in 0.00 s
#   Iteration 35 (0.01 s, search 0.01 s): objective=6.26931e+06 imbalance=1.725 nsplit=0
# Clustering 488 points in 74D to 6 clusters, redo 1 times, 37 iterations
#   Preprocessing in 0.00 s
#   Iteration 36 (0.01 s, search 0.01 s): objective=6.26931e+06 imbalance=1.725 nsplit=0
# Clustering 488 points in 74D to 6 clusters, redo 1 times, 38 iterations
#   Preprocessing in 0.00 s
#   Iteration 37 (0.01 s, search 0.01 s): objective=6.26931e+06 imbalance=1.725 nsplit=0
# Clustering 488 points in 74D to 6 clusters, redo 1 times, 39 iterations
#   Preprocessing in 0.00 s
#   Iteration 38 (0.02 s, search 0.01 s): objective=6.26931e+06 imbalance=1.725 nsplit=0
# Clustering 488 points in 74D to 6 clusters, redo 1 times, 40 iterations
#   Preprocessing in 0.00 s
#   Iteration 39 (0.01 s, search 0.01 s): objective=6.26931e+06 imbalance=1.725 nsplit=0
# Clustering 488 points in 74D to 6 clusters, redo 1 times, 41 iterations
#   Preprocessing in 0.00 s
#   Iteration 40 (0.02 s, search 0.01 s): objective=6.26931e+06 imbalance=1.725 nsplit=0
# Clustering 488 points in 74D to 6 clusters, redo 1 times, 42 iterations
#   Preprocessing in 0.00 s
#   Iteration 41 (0.02 s, search 0.01 s): objective=6.26931e+06 imbalance=1.725 nsplit=0
# Clustering 488 points in 74D to 6 clusters, redo 1 times, 43 iterations
#   Preprocessing in 0.00 s
#   Iteration 42 (0.01 s, search 0.01 s): objective=6.26931e+06 imbalance=1.725 nsplit=0
# Clustering 488 points in 74D to 6 clusters, redo 1 times, 44 iterations
#   Preprocessing in 0.00 s
#   Iteration 43 (0.01 s, search 0.01 s): objective=6.26931e+06 imbalance=1.725 nsplit=0
# Clustering 488 points in 74D to 6 clusters, redo 1 times, 45 iterations
#   Preprocessing in 0.00 s
#   Iteration 44 (0.01 s, search 0.01 s): objective=6.26931e+06 imbalance=1.725 nsplit=0
# Clustering 488 points in 74D to 6 clusters, redo 1 times, 46 iterations
#   Preprocessing in 0.00 s
#   Iteration 45 (0.02 s, search 0.01 s): objective=6.26931e+06 imbalance=1.725 nsplit=0
# Clustering 488 points in 74D to 6 clusters, redo 1 times, 47 iterations
#   Preprocessing in 0.00 s
#   Iteration 46 (0.01 s, search 0.01 s): objective=6.26931e+06 imbalance=1.725 nsplit=0
# Clustering 488 points in 74D to 6 clusters, redo 1 times, 48 iterations
#   Preprocessing in 0.00 s
#   Iteration 47 (0.01 s, search 0.01 s): objective=6.26931e+06 imbalance=1.725 nsplit=0
# Clustering 488 points in 74D to 6 clusters, redo 1 times, 49 iterations
#   Preprocessing in 0.00 s
#   Iteration 48 (0.01 s, search 0.01 s): objective=6.26931e+06 imbalance=1.725 nsplit=0

# %%
# Determine best verbose for clustering

# Compile inertia values
Sum_of_squared_distances = []
v_test = [False, True]

x = data_to_clusters.copy(order='C') # define datasets as x

k = 6 # from previous test
niter = 10 # from previous test
d = x.shape[1]
for v in v_test:
    kmn_model = faiss.Kmeans(d, k, niter=niter, verbose=v)
    kmn_model.train(x)
    D, I = kmn_model.index.search(x, 1)
    Sum_of_squared_distances.append(sum(D))

# Shot k method graph
plt.plot(v_test, Sum_of_squared_distances, 'bx-')
plt.xlabel('verbose')
plt.ylabel('Sum of squared distances')
plt.title('Elbow Method For Optimal k')
plt.show()
# Out:
# Clustering 488 points in 74D to 6 clusters, redo 1 times, 10 iterations
#   Preprocessing in 0.00 s
#   Iteration 9 (0.00 s, search 0.00 s): objective=6.28246e+06 imbalance=1.711 nsplit=0

# %%
# Train K-Means model
x = data_to_clusters.copy(order='C') # define datasets as x

ncentroids = 6
niter = 10
verbose = True
d = x.shape[1]
kmn_model = faiss.Kmeans(d, ncentroids, niter=niter, verbose=verbose)
kmn_model.train(x)
# Out:
# Clustering 488 points in 74D to 6 clusters, redo 1 times, 10 iterations
#   Preprocessing in 0.00 s
#   Iteration 9 (0.00 s, search 0.00 s): objective=6.28246e+06 imbalance=1.711 nsplit=0
# 6282457.0

# %%
# Assign clustering result
D, I = kmn_model.index.search(x, 1)

df['kmn_clusters'] = I

# %%
plt.scatter(df['threshold_yield'],
            df['loss_calculation'],
            c=df['kmn_clusters']
            ,cmap='rainbow')
plt.title("Loss Calculation Values")
plt.xlabel("Threshold Yield")
plt.ylabel("Loss Calculation")
# Out:
# Text(0, 0.5, 'Loss Calculation')

# %% [markdown]
# <h5>Method 2 - Agglomerative Hierarchical Clustering</h5>

# %%
# Import necessary modules
import scipy.cluster.hierarchy as shc
from sklearn.cluster import AgglomerativeClustering

# %%
# Create overall dendogram
plt.figure(figsize=(100, 10))
plt.title("Loss alculation Dendograms")
dend = shc.dendrogram(shc.linkage(x, method='ward'))

plt.axhline(y=max(D), color='r', linestyle='--')

# %%
# Train and assign cluster to dataset
shc_model = AgglomerativeClustering(n_clusters=6, affinity='euclidean', linkage='ward')
df['shc_clusters'] = shc_model.fit_predict(x)

# %%
plt.scatter(df['threshold_yield'],
            df['loss_calculation'],
            c=df['shc_clusters']
            ,cmap='rainbow')
plt.title("Loss Calculation Values")
plt.xlabel("Threshold Yield")
plt.ylabel("Loss Calculation")
# Out:
# Text(0, 0.5, 'Loss Calculation')

# %% [markdown]
# <h5>Method 3 - Density-Based Spatial Clustering of Applications with Noise (DBSCAN)</h5>

# %%
# Import necessary modules
from sklearn.neighbors import NearestNeighbors
from sklearn.cluster import DBSCAN

# %% [markdown]
# For 2-dimensional data, use DBSCAN’s default value of MinPts = 4 (Ester et al., 1996).
# <br/>
# <i>source: https://medium.com/@tarammullin/dbscan-parameter-estimation-ff8330e3a3bd</i>

# %%
# Train model for epsilon optimisation
neighbors = NearestNeighbors(n_neighbors=6)
neighbors_fit = neighbors.fit(x)
distances, indices = neighbors_fit.kneighbors(x)

# %%
# Get distances for epsilon optimasion
distances = np.sort(distances, axis=0)
distances = distances[:,1]
plt.plot(distances)

# %%
# Zoom in to elbow
plt.xlim([400,500])
plt.plot(distances)

# %%
# Train model for dataset and assign cluster to dataset
dbs_model = DBSCAN(eps=1/480, min_samples=4).fit(x)
df['dbs_clusters'] = dbs_model.labels_

# %%
plt.scatter(df['threshold_yield'],
            df['loss_calculation'],
            c=df['dbs_clusters']
            ,cmap='rainbow')
plt.title("Loss Calculation Values")
plt.xlabel("Threshold Yield")
plt.ylabel("Loss Calculation")
# Out:
# Text(0, 0.5, 'Loss Calculation')

# %% [markdown]
# <h5>Method 4 - Mean-Shift Clustering</h5>

# %%
# Import necessary modules
from sklearn.cluster import MeanShift, estimate_bandwidth

# %%
# Train model for dataset and assign cluster to dataset
bandwidth = estimate_bandwidth(x)
msc_model = MeanShift(bandwidth=bandwidth).fit(x)
df['msc_clusters'] = msc_model.labels_

# %%
plt.scatter(df['threshold_yield'],
            df['loss_calculation'],
            c=df['msc_clusters']
            ,cmap='rainbow')
plt.title("Loss Calculation Values")
plt.xlabel("Threshold Yield")
plt.ylabel("Loss Calculation")
# Out:
# Text(0, 0.5, 'Loss Calculation')

# %% [markdown]
# <h3>Chapter 3: Model evaluation</h3>
# <p>This chapter explains the evaluation of models for the dataset and determine the best model to cluster the dataset. The choosen model will be applied across dataset with the same hyperparameters for consistency. To evaluate the model, we will use Davies Bouldin Index.</p>
# <p>Please note that this chapter does not include the analysis of each cluster and definition to business context. Those analyses will be performed on the latter chapters.</p>

# %%
df
# Out:
#                                     ID  threshold_yield  loss_calculation  \
# 0         andhra pradesh_1.0_anantapur         0.001523          0.017028
# 1     andhra pradesh_1.0_east godavari         0.060844          0.185710
# 2            andhra pradesh_1.0_guntur         0.018902          0.068932
# 3           andhra pradesh_1.0_kurnool         0.003742          0.085053
# 4          andhra pradesh_1.0_prakasam         0.108780          0.575644
# ..                                 ...              ...               ...
# 483              west bengal_3.0_malda         0.000325          0.011637
# 484        west bengal_3.0_murshidabad         0.001167          0.071718
# 485              west bengal_3.0_nadia         0.000580          0.082268
# 486  west bengal_3.0_north 24 parganas         0.001026          0.048175
# 487    west bengal_3.0_purba medinipur         0.000872          0.123521
#
#      Average Temperature January (C)  Average Temperature February (C)  \
# 0                               24.3                              26.9
# 1                               23.8                              25.3
# 2                               24.2                              26.1
# 3                               24.6                              27.0
# 4                               24.1                              25.4
# ..                               ...                               ...
# 483                             17.5                              20.8
# 484                             17.8                              21.4
# 485                             18.3                              21.9
# 486                             19.0                              22.7
# 487                             19.4                              23.1
#
#      Average Temperature March (C)  Average Temperature April (C)  \
# 0                             30.2                           32.3
# 1                             27.8                           29.9
# 2                             28.7                           31.0
# 3                             30.3                           32.7
# 4                             27.7                           29.7
# ..                             ...                            ...
# 483                           25.5                           28.5
# 484                           26.2                           29.3
# 485                           26.4                           29.5
# 486                           27.0                           29.8
# 487                           27.3                           30.1
#
#      Average Temperature May (C)  Average Temperature June (C)  \
# 0                           31.7                          28.5
# 1                           31.9                          30.4
# 2                           33.3                          31.3
# 3                           33.1                          29.2
# 4                           32.3                          31.5
# ..                           ...                           ...
# 483                         28.9                          28.9
# 484                         29.5                          29.2
# 485                         29.9                          29.3
# 486                         30.4                          29.4
# 487                         30.8                          29.8
#
#      Average Temperature July (C)  ...  Average Sun Hours July  \
# 0                            27.2  ...                     8.3
# 1                            28.6  ...                    10.1
# 2                            29.4  ...                    10.4
# 3                            27.5  ...                     8.4
# 4                            30.0  ...                    10.5
# ..                            ...  ...                     ...
# 483                          28.2  ...                     7.3
# 484                          28.1  ...                     7.7
# 485                          28.1  ...                     7.9
# 486                          28.1  ...                     8.1
# 487                          28.3  ...                     8.5
#
#      Average Sun Hours August  Average Sun Hours September  \
# 0                         7.9                          8.4
# 1                         9.7                          9.0
# 2                         9.8                          9.2
# 3                         8.0                          8.1
# 4                        10.1                          9.6
# ..                        ...                          ...
# 483                       7.5                          7.4
# 484                       7.7                          7.6
# 485                       7.8                          7.8
# 486                       7.8                          7.9
# 487                       8.1                          8.1
#
#      Average Sun Hours October  Average Sun Hours November  \
# 0                          8.6                         8.0
# 1                          8.7                         8.9
# 2                          8.5                         8.2
# 3                          8.8                         8.6
# 4                          8.6                         7.8
# ..                         ...                         ...
# 483                        8.5                         8.9
# 484                        8.5                         8.9
# 485                        8.4                         9.0
# 486                        8.3                         8.9
# 487                        8.4                         8.9
#
#      Average Sun Hours December  kmn_clusters  shc_clusters  dbs_clusters  \
# 0                           8.1             3             0            -1
# 1                           8.7             3             0            -1
# 2                           7.8             3             0            -1
# 3                           8.8             3             0            -1
# 4                           7.4             3             0            -1
# ..                          ...           ...           ...           ...
# 483                         8.3             1             4            -1
# 484                         8.5             1             4            -1
# 485                         8.6             1             4            -1
# 486                         8.7             1             4            -1
# 487                         8.8             1             4            -1
#
#      msc_clusters
# 0               0
# 1               0
# 2               0
# 3               0
# 4               0
# ..            ...
# 483             0
# 484             0
# 485             0
# 486             0
# 487             0
#
# [488 rows x 79 columns]

# %%
for cluster in ['kmn', 'shc', 'dbs', 'msc']:
    try:
        score = metrics.davies_bouldin_score(x, df[cluster+'_clusters'])
        print(cluster, '> # of clusters:', len(df[cluster+'_clusters'].unique()), '| DBI:', score)
    except:
        pass
# Out:
# kmn > # of clusters: 6 | DBI: 0.8345254521290487
# shc > # of clusters: 6 | DBI: 0.8615540966714574
# dbs > # of clusters: 4 | DBI: 4.4804875420061645
# msc > # of clusters: 9 | DBI: 0.5637601741865021

# %%
# Export csv before clustering for performance improvement
df.to_csv("datasets_clustered/rabi_clustered_done.csv", sep=';')

# %%
# Export selected model
model = shc_model
pickle.dump(model, open("clustering_models/model_rabi_level.pkl", "wb"))
